# %%
import pandas as pd
import numpy as np
import random
import json

pd.read_excel("output_final.xlsx")
output_df = pd.read_excel("output_final.xlsx")

"select mammography"
wd = output_df[:8]
name = wd['Name'].values.tolist()[0:1]
"create list of values and slice empty entities from list"
cd = wd['Condition description'].values.tolist()[0:1]
f_list = wd['Relevant findings']
"random finding"
f = random.choice(f_list)
un_list = wd['Unique findings'].values.tolist()
un = random.choice(u_list)
"empty - but will leave here just in case"
p_list = wd['Parameters']
p = random.choice(p_list)
t_list = wd['Typical'].values.tolist()
t = random.choice(t_list)
pos_list = wd['Possible']
pos = random.choice(pos_list)
u_list = wd['Unrelated'].values.tolist()
u = random.choice(u_list)
n_list = wd['Negative'].values.tolist()
n = random.choice(n_list)
i_list = wd['Ignore'].values.tolist()
i = random.choice(i_list)
a_list = wd['Associated conditions'].tolist()
a = random.choice(a_list)
dd_list = wd['Differential diagnosis'].tolist()
dd = random.choice(dd_list)
nt_list = wd['Notes'].tolist()
nt = random.choice(nt_list)

params = ["name", "condition description", "relevant finding", "unique finding", "parameters", 
          "typical", "possible", "unrelated", "negative", "ignore", "associated conditions", "notes"]
keys = [name, cd, f, un, p, t, pos, u, n, i, a, dd, nt]

rep = {}
for i in range(len(params)):
    rep[params[i]] = keys[i]
    
rep = json.dumps(rep)
print(rep)

wd
# Out:
# {"name": ["Fibroadenoma"], "condition description": ["Fibroadenomas are the most common cause of a benign solid mass in the breast."], "relevant finding": "Mass", "unique finding": "Large rod-like", "parameters": "Lymph nodes", "typical": "Oval, Round", "possible": NaN, "unrelated": "Diffuse, Regional, Grouped, Linear, Segmental", "negative": NaN, "ignore": NaN, "associated conditions": NaN, "notes": NaN}
#            Name                              Condition description  birad[0]  \
# 0  Fibroadenoma  Fibroadenomas are the most common cause of a b...       1.0
# 1           NaN                                                NaN       NaN
# 2           NaN                                                NaN       NaN
# 3           NaN                                                NaN       NaN
# 4           NaN                                                NaN       NaN
# 5           NaN                                                NaN       NaN
# 6           NaN                                                NaN       NaN
# 7           NaN                                                NaN       NaN
#
#    birad[1]  birad[2]  birad[3]  birad[4] birad[5]  birad[6]  \
# 0       1.0      50.0      30.0       1.0        1       1.0
# 1       NaN       NaN       NaN       NaN      NaN       NaN
# 2       NaN       NaN       NaN       NaN      NaN       NaN
# 3       NaN       NaN       NaN       NaN      NaN       NaN
# 4       NaN       NaN       NaN       NaN      NaN       NaN
# 5       NaN       NaN       NaN       NaN      NaN       NaN
# 6       NaN       NaN       NaN       NaN      NaN       NaN
# 7       NaN       NaN       NaN       NaN      NaN       NaN
#
#   Relevant modalities  ...                    Typical  \
# 0         Mammography  ...                Oval, Round
# 1         Mammography  ...              Circumscribed
# 2         Mammography  ...                       Skin
# 3         Mammography  ...   Coarse or “popcorn-like”
# 4         Mammography  ...                        NaN
# 5         Mammography  ...                        NaN
# 6         Mammography  ...                        NaN
# 7         Mammography  ...                        NaN
#
#                              Possible   Atypical Pathogenomonic  \
# 0                                 NaN  Irregular            NaN
# 1                                 NaN        NaN            NaN
# 2  Vascular, Coarse or “popcorn-like”        NaN            NaN
# 3                                 NaN        NaN            NaN
# 4                                 NaN        NaN            NaN
# 5                                 NaN        NaN            NaN
# 6                                 NaN        NaN            NaN
# 7                                 NaN        NaN            NaN
#
#                                            Unrelated Negative Ignore  \
# 0                                                NaN      NaN    NaN
# 1                                                NaN      NaN    NaN
# 2                                     Large rod-like      NaN    NaN
# 3  Skin, Vascular, Large rod-like, Round, Rim, Dy...      NaN    NaN
# 4  Amorphous, Coarse heterogeneous, Fine pleomorp...      NaN    NaN
# 5      Diffuse, Regional, Grouped, Linear, Segmental      NaN    NaN
# 6  Asymmetry, Global asymmetry, Focal asymmetry, ...      NaN    NaN
# 7  Lymph nodes – intramammary, Lymph nodes – axil...      NaN    NaN
#
#    Associated conditions Differential diagnosis Notes
# 0                   None             Breast Ca.   NaN
# 1                    NaN                    NaN   NaN
# 2                    NaN                    NaN   NaN
# 3                    NaN                    NaN   NaN
# 4                    NaN                    NaN   NaN
# 5                    NaN                    NaN   NaN
# 6                    NaN                    NaN   NaN
# 7                    NaN                    NaN   NaN
#
# [8 rows x 24 columns]
